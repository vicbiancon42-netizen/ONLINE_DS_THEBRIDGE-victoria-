# %% [markdown]
# <a href="https://colab.research.google.com/github/vicbiancon42-netizen/ONLINE_DS_THEBRIDGE-victoria-/blob/main/Ejercicio_pr%C3%A1ctico_Python_Avanzado.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PRACTICA OBLIGATORIA: COLECCIONES Y FUNCIONES

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste varios ejercicios de programación libre a completar sobre Colecciones y Funciones. Descarga este notebook en tu ordenador y trabaja en local.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente y puedas participar en dicha sesión.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Contenidos

# %% [markdown]
# ## Ejercicio 1
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]

ejer_2_cuadrado = []
for x in ejer_2:
    ejer_2_cuadrado.append(x**2)

print("Lista original:", ejer_2)
print("Lista al cuadrado:", ejer_2_cuadrado)
# Out:
# Lista original: [1, 2, 3, 4, 5]
# Lista al cuadrado: [1, 4, 9, 16, 25]

# %% [markdown]
# ## Ejercicio 2
# Haz un programa que detecte todos los duplicados de un elemento en una lista:
# * Utiliza una variable duplicado para asignarle el valor del elemento del que queremos encontrar todos sus duplicados.
# * El programa debe devolver todos los índices de los elementos duplicados.
# * Aplícalo para encontrar los duplicados de "un", "es" y "binario" de:
#
# >```ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]```

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular",
          "a", "veces", "no", "es", "ni", "binario", "ni", "árbol"]

def indices_duplicados(lista, duplicado):
    indices = []
    for i, valor in enumerate(lista):
        if str(valor).lower() == str(duplicado).lower():
            indices.append(i)
    return indices

for palabra in ["un", "es", "binario"]:
    print(f'Duplicados de "{palabra}":', indices_duplicados(ejer_3, palabra))
# Out:
# Duplicados de "un": [0, 7]
# Duplicados de "es": [3, 13]
# Duplicados de "binario": [2, 15]

# %% [markdown]
# ## Ejercicio 3
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_3`?
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

# 1) ¿Cuántas veces se repite el 3 en la siguiente tupla?
print("1) Veces que aparece el 3:", ejer_9.count(3))

# 2) Tupla nueva desde la posición 5 a la 10 (incluyendo 10)
nueva_tupla = ejer_9[5:11]
print("2) Tupla posiciones 5 a 10:", nueva_tupla)

# 3) ¿Cuántos elementos tiene la tupla ejer_3?
print("3) Número de elementos:", len(ejer_3))
# Out:
# 1) Veces que aparece el 3: 7
# 2) Tupla posiciones 5 a 10: (3, 29, 45, 67, 78, 90)
# 3) Número de elementos: 18

# %% [markdown]
# ## Ejercicio 4
# Comprueba si el numero 60 esta en la tupla del ejercicio 3

# %%
ejer_3 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

print("¿Está el 60 en la tupla?:", 60 in ejer_3)
# Out:
# ¿Está el 60 en la tupla?: False

# %% [markdown]
# ## Ejercicio 5
# 1. Convierte la tupla del ejercicio 3 en una lista
# 2. Convierte la tupla del ejercicio 3 en un set
# 3. Convierte la tupla del ejercicio 3 en un diccionario. Usa también los indices

# %%
ejer_3 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)

# 1) Convertir a lista
lista_ejer_3 = list(ejer_3)
print("1) Lista:", lista_ejer_3)

# 2) Convertir a set
set_ejer_3 = set(ejer_3)
print("2) Set:", set_ejer_3)

# 3) Convertir a diccionario usando índices
dic_ejer_3 = {}

for i, valor in enumerate(ejer_3):
    dic_ejer_3[i] = valor

print("3) Diccionario (indice -> valor):", dic_ejer_3)
# Out:
# 1) Lista: [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]
# 2) Set: {2, 3, 67, 5, 4, 7, 6, 9, 45, 78, 47, 19, 20, 90, 29}
# 3) Diccionario (indice -> valor): {0: 3, 1: 20, 2: 3, 3: 47, 4: 19, 5: 3, 6: 29, 7: 45, 8: 67, 9: 78, 10: 90, 11: 3, 12: 3, 13: 5, 14: 2, 15: 4, 16: 7, 17: 9, 18: 4, 19: 2, 20: 4, 21: 3, 22: 3, 23: 4, 24: 6, 25: 7}

# %% [markdown]
# ## Ejercicio 6
# Multiplica todos los valores del diccionario
# > ```ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

producto = 1
for v in ejer_6.values():
    producto *= v

print("Diccionario:", ejer_6)
print("Producto de todos los valores:", producto)
# Out:
# Diccionario: {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}
# Producto de todos los valores: 19326120

# %% [markdown]
# ## Ejercicio 7
#
# 1. Crea un diccionario que describa un libro, con los siguientes campos o claves: "titulo","autor","idioma original","año de publicación".
# 2. Crea un a lista, llamada librería.
# 3. Añade cuatro libros a tu elección a la librería.

# %%
# 1) Crea un diccionario que describa un libro
libro = {
    "titulo": "Man's Search for Meaning",
    "autor": "Viktor Frankl",
    "idioma original": "alemán",
    "año de publicación": 1946
}
print("1) Ejemplo de libro:", libro)

# 2) Crea una lista llamada libreria
libreria = []
print("2) Librería (vacía):", libreria)

# 3) Añade cuatro libros a tu elección a la libreria
libreria.append({
    "titulo": "Man's Search for Meaning",
    "autor": "Viktor Frankl",
    "idioma original": "alemán",
    "año de publicación": 1946
})

libreria.append({
    "titulo": "La empleada",
    "autor": "Freida McFadden",
    "idioma original": "inglés",
    "año de publicación": 2022
})

libreria.append({
    "titulo": "Cadáver exquisito",
    "autor": "Agustina Bazterrica",
    "idioma original": "español",
    "año de publicación": 2017
})

libreria.append({
    "titulo": "Daisy Jones and the Six",
    "autor": "Taylor Jenkins Reid",
    "idioma original": "inglés",
    "año de publicación": 2019
})

print("3) Librería con 4 libros:")
for libro in libreria:
    print(libro)
# Out:
# 1) Ejemplo de libro: {'titulo': "Man's Search for Meaning", 'autor': 'Viktor Frankl', 'idioma original': 'alemán', 'año de publicación': 1946}
# 2) Librería (vacía): []
# 3) Librería con 4 libros:
# {'titulo': "Man's Search for Meaning", 'autor': 'Viktor Frankl', 'idioma original': 'alemán', 'año de publicación': 1946}
# {'titulo': 'La empleada', 'autor': 'Freida McFadden', 'idioma original': 'inglés', 'año de publicación': 2022}
# {'titulo': 'Cadáver exquisito', 'autor': 'Agustina Bazterrica', 'idioma original': 'español', 'año de publicación': 2017}
# {'titulo': 'Daisy Jones and the Six', 'autor': 'Taylor Jenkins Reid', 'idioma original': 'inglés', 'año de publicación': 2019}

# %% [markdown]
# ## Ejercicio 8
# Modifica los valores del idioma de todos los libros del ejercicio anterior para que sea "esperanto"

# %%
# Partimos de la librería del ejercicio 7
for libro in libreria:
    libro["idioma original"] = "esperanto"

print("Librería con idioma modificado:")
for libro in libreria:
    print(libro)
# Out:
# Librería con idioma modificado:
# {'titulo': "Man's Search for Meaning", 'autor': 'Viktor Frankl', 'idioma original': 'esperanto', 'año de publicación': 1946}
# {'titulo': 'La empleada', 'autor': 'Freida McFadden', 'idioma original': 'esperanto', 'año de publicación': 2022}
# {'titulo': 'Cadáver exquisito', 'autor': 'Agustina Bazterrica', 'idioma original': 'esperanto', 'año de publicación': 2017}
# {'titulo': 'Daisy Jones and the Six', 'autor': 'Taylor Jenkins Reid', 'idioma original': 'esperanto', 'año de publicación': 2019}

# %% [markdown]
# ## Ejercicio 9
# 1. Escribe un programa que dada una variable titulo busque los libros que hay en la librería con ese título. Si no se encuentra debe devolver el mensaje `Ese no lo tengo, ¿mola?`
# 2. Pruena que el programa con uno de tus libros y con otro que no contenga tu librería.

# %%
# 1) Buscar un libro por título
titulo = "La empleada"  # prueba con uno que SÍ exista

encontrado = False

for libro in libreria:
    if libro["titulo"].lower() == titulo.lower():
        print("Encontrado:", libro)
        encontrado = True

if not encontrado:
    print("Ese no lo tengo, ¿mola?")


# 2) Probar con otro que NO exista
titulo = "El señor de los anillos"

encontrado = False

for libro in libreria:
    if libro["titulo"].lower() == titulo.lower():
        print("Encontrado:", libro)
        encontrado = True

if not encontrado:
    print("Ese no lo tengo, ¿mola?")
# Out:
# Encontrado: {'titulo': 'La empleada', 'autor': 'Freida McFadden', 'idioma original': 'esperanto', 'año de publicación': 2022}
# Ese no lo tengo, ¿mola?

# %% [markdown]
# ## Ejercicio 10
# Convierte el programa del ejercicio 2 en una función al que se le pase el valor a buscar como un argumento posicional

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular",
          "a", "veces", "no", "es", "ni", "binario", "ni", "árbol"]

def buscar_duplicados(lista, duplicado):
    indices = []
    for i, valor in enumerate(lista):
        if str(valor).lower() == str(duplicado).lower():
            indices.append(i)
    return indices

print('Duplicados de "un":', buscar_duplicados(ejer_3, "un"))
print('Duplicados de "es":', buscar_duplicados(ejer_3, "es"))
print('Duplicados de "binario":', buscar_duplicados(ejer_3, "binario"))
# Out:
# Duplicados de "un": [0, 7]
# Duplicados de "es": [3, 13]
# Duplicados de "binario": [2, 15]

# %% [markdown]
# ## Ejercicio 11
# Convierte el programa del ejercicio 9 en una función al que se le pasen como argumentos la librería, posicional, y el título, argumento keyword con valor "ninguno", por defecto.

# %%
def buscar_libro(libreria, titulo="ninguno"):
    for libro in libreria:
        if libro["titulo"].lower() == titulo.lower():
            return libro
    return "Ese no lo tengo, ¿mola?"


# Probamos con uno que existe
print(buscar_libro(libreria, titulo="Daisy Jones and the Six"))

# Probamos con uno que NO existe
print(buscar_libro(libreria, titulo="Harry Potter"))

# Probamos usando el valor por defecto
print(buscar_libro(libreria))
# Out:
# {'titulo': 'Daisy Jones and the Six', 'autor': 'Taylor Jenkins Reid', 'idioma original': 'esperanto', 'año de publicación': 2019}
# Ese no lo tengo, ¿mola?
# Ese no lo tengo, ¿mola?

# %% [markdown]
# ## Ejercicio 12
# Solicitar al usuario que ingrese su dirección email. Imprimir un mensaje indicando si la dirección es válida o no, valiéndose de una función para decidirlo. Una dirección se considerará válida si contiene el símbolo "@".

# %%
def email_valido(email):
    return "@" in email

email = input("Introduce tu email: ")

if email_valido(email):
    print("Email válido")
else:
    print("Email NO válido")
# Out:
# Introduce tu email: vicbiancongmail.com
# Email NO válido

# %% [markdown]
# ## Ejercicio 13
# Escribe una función que compruebe si un DNI es válido, devolviendo `True` en caso afirmativo.
# En primer lugar, el DNI debe tener entre 7 y 8 dígitos numéricos.
# Para saber si la letra del DNI es correcta puedes utilizar el siguiente fragmento de código:
# >```Python
# >DNI= 55555555
# >palabra='TRWAGMYFPDXBNJZSQVHLCKE'
# >print('La letra del DNI es: ', palabra[DNI%23])
# >````

# %%
def dni_valido(dni):
    dni = dni.strip().upper()

    # Debe ser: 7-8 dígitos + 1 letra
    if len(dni) not in [8, 9]:
        return False

    numero = dni[:-1]
    letra = dni[-1]

    if not numero.isdigit():
        return False

    if len(numero) not in [7, 8]:
        return False

    palabra = "TRWAGMYFPDXBNJZSQVHLCKE"
    letra_correcta = palabra[int(numero) % 23]

    return letra == letra_correcta

dni_usuario = input("Introduce tu DNI (ej: 55555555T): ")
print("¿DNI válido?:", dni_valido(dni_usuario))
# Out:
# Introduce tu DNI (ej: 55555555T): 988888
# ¿DNI válido?: False
