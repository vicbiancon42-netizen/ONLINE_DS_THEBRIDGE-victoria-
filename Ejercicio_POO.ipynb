# %% [markdown]
# <a href="https://colab.research.google.com/github/vicbiancon42-netizen/ONLINE_DS_THEBRIDGE-victoria-/blob/main/Ejercicio_POO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ejercicios Clases y Objetos

# %% [markdown]
# ## Ejercicio 1
# Somos una empresa que tiene varias tiendas de electrodomesticos. Necesitamos un programa para manejar las tiendas, ver las ventas que han tenido, cuántos empleados hay, etc... Para ello vamos a modelizar la tienda en una clase, que tendrá las siguientes características:
# * Nombre clase: "Tienda"
# * Atributos comunes:
#     * Tipo: "Electrodomésticos"
#     * Abierta: True
# * Atributos propios de cada tienda:
#     * Nombre - String
#     * Dirección - String
#     * Número de empleados - int
#     * Ventas ultimos 3 meses - Lista de 3 numeros
# * Método para calcular las ventas de todos los meses, que devuelva un numero con todas las ventas.
# * Método que calcula la media de ventas de los ultimos meses, por empleado
# * Método que devuelve en un string el nombre de la tienda, junto con su dirección.
# * Método que obtiene las ventas del último mes.
# * Método para dar una proyección de las ventas en caso de haber invertido X dinero en marketing en esa tienda. Siendo X el parámetro de entrada. Si X es menor de 1000, las ventas de los ultimos 3 meses hubiesen sido de (1.2 x ventas), si es mayor o igual de 1000, las ventas hubiesen sido de (1.5 x venta). El método reescribe el atributo de ventas en los últimos 3 meses, y además devuelve las ventas con el aumento.
#
# Se pide:
# 1. Implementar la clase "Tienda"
# 2. Crear tres tiendas con datos inventados
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
# 3. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle `for`
# 4. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
# 5. Seguro que ya has hecho este apartado... Documenta la clase :)

# %%
# 1. Implementar la clase "Tienda"

class Tienda:

    tipo = "Electrodomésticos"
    abierta = True

    def __init__(self, nombre, direccion, num_empleados, ventas_ultimos_3_meses):
        self.nombre = nombre
        self.direccion = direccion
        self.num_empleados = num_empleados
        self.ventas_ultimos_3_meses = ventas_ultimos_3_meses

    def ventas_totales(self):
        total = 0
        for venta in self.ventas_ultimos_3_meses:
            total = total + venta
        return total

    def media_ventas_por_empleado(self):
        total = self.ventas_totales()
        media = total / self.num_empleados
        return media

    def info_tienda(self):
        return self.nombre + " - " + self.direccion

    def ventas_ultimo_mes(self):
        return self.ventas_ultimos_3_meses[2]

    def proyeccion_marketing(self, inversion):

        if inversion < 1000:
            factor = 1.2
        else:
            factor = 1.5

        nuevas_ventas = []

        for venta in self.ventas_ultimos_3_meses:
            nuevas_ventas.append(venta * factor)

        self.ventas_ultimos_3_meses = nuevas_ventas

        return self.ventas_ultimos_3_meses

# %%
# 2. Crear tres tiendas con datos inventados
tienda_1 = Tienda("ElectroSur", "Avenida Central 123", 5, [10000, 12000, 11000])
tienda_2 = Tienda("ElectroNorte", "Calle Mayor 45", 3, [8000, 7500, 9000])
tienda_3 = Tienda("ElectroEste", "Avenida Libertad 78", 4, [15000, 14000, 16000])

# %%
# 3. Comprueba en al menos una de ellas, todo lo implementado en la clase tienda (sus atributos, media de ventas, ventas/empleado...)
print(tienda_1.tipo)
print(tienda_1.abierta)
print(tienda_1.ventas_totales())
print(tienda_1.media_ventas_por_empleado())
print(tienda_1.info_tienda())
print(tienda_1.ventas_ultimo_mes())
# Out:
# Electrodomésticos
# True
# 33000
# 6600.0
# ElectroSur - Avenida Central 123
# 11000

# %%
# 4. Calcular las ventas del último mes de todas las tiendas. Para ello usa el bucle for
for tienda in [tienda_1, tienda_2, tienda_3]:
    print(tienda.nombre, tienda.ventas_ultimo_mes())
# Out:
# ElectroSur 11000
# ElectroNorte 9000
# ElectroEste 16000

# %%
# 5. Imprime por pantalla los nombres de las tiendas cuya dirección lleve el string "Avenida"
for tienda in [tienda_1, tienda_2, tienda_3]:
    if "Avenida" in tienda.direccion:
        print(tienda.nombre)
# Out:
# ElectroSur
# ElectroEste

# %%
class Tienda:
    """
    Clase que representa una tienda de electrodomésticos.

    Permite:
    - Guardar el nombre, dirección, empleados y ventas.
    - Calcular ventas totales.
    - Calcular media de ventas por empleado.
    - Obtener ventas del último mes.
    - Hacer proyección de marketing.
    """

# %% [markdown]
# ## Ejercicio 2
# En este ejercicio vamos a implementar una clase *Perro* en Python. La clase tiene las siguientes características:
# * Cosas que sabemos seguro que tiene un perro
#     * Tiene 4 patas
#     * 2 orejas
#     * 2 ojos
#     * Una velocidad de 0. Por defecto, el perro está parado
# * Cuando se inicialice:
#     * El perro será de una determinada raza
#     * Por defecto tendrá pelo "Marrón", a no ser que se diga lo contrario.
#     * Por defecto no tendrá dueño, a no ser que se diga lo contrario.
#
# * Dispondrá también de un método llamado andar, que tiene un argumento de entrada (aumento_velocidad). Este valor se le sumará a la velocidad que ya llevaba el perro.
# * Necesita otro método (parar), donde pondremos la velocidad a 0.
# * Otro método llamado "ladrar", que tendrá un argumento de entrada, y la salida será el siguiente string: "GUAU!" + el argumento de entrada.
#
#
# Se pide:
# * Implementa la clase *Perro*
# * Crea un objeto de tipo *Perro*, sin dueño
# * Comprueba que están bien todos sus atributos
# * Prueba que ande, y comprueba su velocidad
# * Páralo
# * Documenta la clase *Perro*

# %%
class Perro:

    patas = 4
    orejas = 2
    ojos = 2

    def __init__(self, raza, color="Marrón", dueno=None):
        self.raza = raza
        self.color = color
        self.dueno = dueno
        self.velocidad = 0

    def andar(self, aumento_velocidad):
        self.velocidad = self.velocidad + aumento_velocidad

    def parar(self):
        self.velocidad = 0

    def ladrar(self, mensaje):
        return "AU! " + mensaje

# %%
# 1. Crea un objeto de tipo Perro, sin dueño
perro_1 = Perro("Labrador")
print(perro_1.dueno)
# Out:
# None

# %%
# 2. Comprueba que están bien todos sus atributos
print("Raza:", perro_1.raza)
print("Color:", perro_1.color)
print("Dueño:", perro_1.dueno)
print("Velocidad:", perro_1.velocidad)

print("Patas:", perro_1.patas)
print("Orejas:", perro_1.orejas)
print("Ojos:", perro_1.ojos)
# Out:
# Raza: Labrador
# Color: Marrón
# Dueño: None
# Velocidad: 0
# Patas: 4
# Orejas: 2
# Ojos: 2

# %%
# 3. Prueba que ande, y comprueba su velocidad
perro_1.andar(10)
print("Velocidad después de andar:", perro_1.velocidad)
# Out:
# Velocidad después de andar: 10

# %%
 # 4. Páralo
perro_1.parar()
print("Velocidad después de parar:", perro_1.velocidad)
# Out:
# Velocidad después de parar: 0

# %%
class Perro:
    """
    Clase que representa un perro.

    Tiene atributos comunes como patas, orejas y ojos.
    Al crearse, recibe una raza y puede tener color y dueño.
    Permite andar, parar y ladrar.
    """
